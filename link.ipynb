# %%
Smart-Lender
│
├── app.py
├── rdf.pkl
├── loan_prediction.csv
├── requirements.txt
│
├── templates
│     home.html
│     predict.html
│     submit.html
│
├── static
│     style.css
│
└── model_training.py
pip install numpy
pip install pandas
pip install matplotlib
pip install seaborn
pip install scikit-learn
pip install flask
pip install pickle-mixin
pip install numpy pandas matplotlib seaborn scikit-learn flask pickle-mixin
import numpy
import pandas
import matplotlib
import seaborn
import sklearn
import flask

print("All libraries installed successfully")
import numpy as np
import pandas as pd
import pickle

import matplotlib.pyplot as plt
import seaborn as sns

from flask import Flask, render_template, request

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import LabelEncoder

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
numpy
pandas
matplotlib
seaborn
scikit-learn
flask
pickle-mixin
pip install -r requirements.txt
| Step               | Tool Used                 |
| ------------------ | ------------------------- |
| Data Collection    | Pandas                    |
| Data Cleaning      | Pandas                    |
| Data Visualization | Matplotlib, Seaborn       |
| Feature Encoding   | Scikit-learn              |
| Train/Test Split   | Scikit-learn              |
| Model Training     | Scikit-learn              |
| Cross Validation   | Scikit-learn              |
| Save Model         | Pickle                    |
| Build Web App      | Flask                     |
| Run Project        | PyCharm / Anaconda Prompt |
Install Software
        │
        ▼
Install Python Libraries
        │
        ▼
Load Dataset using Pandas
        │
        ▼
Data Cleaning
        │
        ▼
Data Visualization
        │
        ▼
Feature Engineering
        │
        ▼
Train Machine Learning Models
        │
        ▼
Evaluate Performance
        │
        ▼
Save Best Model (rdf.pkl)
        │
        ▼
Develop Flask Web Application
        │
        ▼
Deploy and Test Loan Prediction System
