# %%
from sklearn.metrics import accuracy_score
from sklearn import metrics
p1 = dtree.predict(x_test)

p2 = rf.predict(x_test)

p3 = knn.predict(x_test)

p4 = xgb.predict(x_test)
from sklearn import metrics

print("Decision Tree Accuracy :", metrics.accuracy_score(y_test, p1))

print("Random Forest Accuracy :", metrics.accuracy_score(y_test, p2))

print("KNN Accuracy           :", metrics.accuracy_score(y_test, p3))

print("XGBoost Accuracy       :", metrics.accuracy_score(y_test, p4))
import pandas as pd

accuracy = {

    "Model":[
        "Decision Tree",
        "Random Forest",
        "KNN",
        "XGBoost"
    ],

    "Accuracy":[

        metrics.accuracy_score(y_test,p1),

        metrics.accuracy_score(y_test,p2),

        metrics.accuracy_score(y_test,p3),

        metrics.accuracy_score(y_test,p4)

    ]

}

comparison = pd.DataFrame(accuracy)

print(comparison)
best_model = comparison.loc[comparison["Accuracy"].idxmax()]

print(best_model)
from sklearn import metrics
import pandas as pd

# Predictions
p1 = dtree.predict(x_test)

p2 = rf.predict(x_test)

p3 = knn.predict(x_test)

p4 = xgb.predict(x_test)

# Accuracy values
dt_acc = metrics.accuracy_score(y_test,p1)

rf_acc = metrics.accuracy_score(y_test,p2)

knn_acc = metrics.accuracy_score(y_test,p3)

xgb_acc = metrics.accuracy_score(y_test,p4)

print("Decision Tree :",dt_acc)

print("Random Forest :",rf_acc)

print("KNN :",knn_acc)

print("XGBoost :",xgb_acc)

# Comparison Table
comparison = pd.DataFrame({

    "Model":[
        "Decision Tree",
        "Random Forest",
        "KNN",
        "XGBoost"
    ],

    "Accuracy":[
        dt_acc,
        rf_acc,
        knn_acc,
        xgb_acc
    ]

})

print("\nModel Comparison")

print(comparison)

# Best Model
best_model = comparison.loc[comparison["Accuracy"].idxmax()]

print("\nBest Model")

print(best_model)
