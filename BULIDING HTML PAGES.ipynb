# %%
Flood_Prediction/
│
├── app.py
├── flood_model.pkl
├── scaler.pkl
│
├── templates/
│   ├── home.html
│   ├── index.html
│   ├── chance.html
│   └── no_chance.html
│
├── static/
│   ├── main.css
│   ├── main.js
│   └── flood.jpg
│
└── dataset/
    └── flood_dataset.xlsx
    <!DOCTYPE html>
<html>
<head>
    <title>Flood Prediction</title>
    <link rel="stylesheet" href="{{ url_for('static', filename='main.css') }}">
</head>

<body>

<header>

<h1>Flood Prediction</h1>

<nav>

<a href="/">Home</a>

<a href="/predict">Predict Floods</a>

</nav>

</header>

<div class="container">

<h2>Introduction</h2>

<p>

Flood forecasting predicts whether flooding may occur based on weather
conditions such as rainfall, cloud cover, humidity, and seasonal rainfall.

</p>

<br>

<a href="/predict">

<button>Predict Flood</button>

</a>

</div>

</body>
</html>
<!DOCTYPE html>
<html>

<head>

<title>Flood Prediction</title>

<link rel="stylesheet" href="{{ url_for('static', filename='main.css') }}">

</head>

<body>

<header>

<h1>Flood Prediction</h1>

</header>

<div class="container">

<form action="/prediction" method="POST">

<label>Cloud Cover</label>

<input type="number" name="cloud" required>

<label>Annual Rainfall</label>

<input type="number" step="0.01" name="annual" required>

<label>Jan-Feb Rainfall</label>

<input type="number" step="0.01" name="janfeb" required>

<label>March-May Rainfall</label>

<input type="number" step="0.01" name="marchmay" required>

<label>June-September Rainfall</label>

<input type="number" step="0.01" name="junsep" required>

<br><br>

<input type="submit" value="Predict">

</form>

</div>

</body>

</html>
<!DOCTYPE html>

<html>

<head>

<title>Result</title>

</head>

<body>

<h1 style="color:red; text-align:center;">

⚠ Flood Likely

</h1>

<br>

<center>

<a href="/">Home</a>

</center>

</body>

</html>
<!DOCTYPE html>

<html>

<head>

<title>Result</title>

</head>

<body>

<h1 style="color:green;text-align:center;">


</h1>

<br>

<center>

<a href="/">Home</a>

</center>

</body>

</html>
body{

margin:0;

font-family:Arial;

background:#f2f2f2;

}

header{

background:black;

color:white;

padding:15px;

}

header h1{

display:inline;

color:lime;

}

nav{

float:right;

}

nav a{

color:white;

text-decoration:none;

padding:10px;

}

.container{

width:70%;

margin:auto;

margin-top:40px;

}

input{

width:250px;

padding:10px;

margin:10px;

}

button,input[type=submit]{

padding:10px 20px;

background:green;

color:white;

border:none;

cursor:pointer;

}
