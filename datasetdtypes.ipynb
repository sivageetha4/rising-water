# %%
# Read the dataset
import pandas as pd

dataset = pd.read_excel('flood dataset.xlsx')
dataset = pd.read_excel(r'C:\Users\YourName\Documents\flood dataset.xlsx')
# Display first 5 rows
dataset.head()
dataset.head(10)
dataset.tail()
dataset.shape
(5000, 12)
dataset.info()
<class 'pandas.core.frame.DataFrame'>

RangeIndex: 5000 entries

Data columns (total 12 columns)

Rainfall          float64

Temperature       float64

Humidity          float64

Flood             int64
dataset.describe()
dataset.columns
Index(['Rainfall',
       'Humidity',
       'Temperature',
       'River_Level',
       'Flood'],
      dtype='object')
      dataset.dtypes
      Rainfall        float64

Humidity        float64

Flood             int64
dataset.isnull().sum()
Rainfall        0

Humidity        0

Flood           0
dataset.fillna(dataset.mean(numeric_only=True), inplace=True)
dataset.fillna(dataset.mode().iloc[0], inplace=True)
dataset.isnull().sum()
dataset.duplicated().sum()
dataset.drop_duplicates(inplace=True)dataset['Flood'].value_counts()
dataset.sample(5)
dataset.to_csv('cleaned_flood_dataset.csv', index=False)
# Import library
import pandas as pd

# Read Excel file
dataset = pd.read_excel('flood dataset.xlsx')

# Display first five rows
print(dataset.head())

# Display last five rows
print(dataset.tail())

# Dataset dimensions
print("Shape:", dataset.shape)

# Dataset information
print(dataset.info())

# Statistical summary
print(dataset.describe())

# Column names
print(dataset.columns)

# Data types
print(dataset.dtypes)

# Missing values
print(dataset.isnull().sum())

# Remove duplicate rows
dataset.drop_duplicates(inplace=True)

# Display target variable distribution
print(dataset['Flood'].value_counts())
