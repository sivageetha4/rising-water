# %%
FloodPrediction.ipynb
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_excel("flood_dataset.xlsx")
df.head()
df.shape
df.columns
Index([
'Temp',
'Humidity',
'Cloud Cover',
'ANNUAL',
'JUN-SEP',
'Oct-Dec',
'Jan-Feb',
'Mar-May',
'Flood',
...
])
df.info()
<class 'pandas.core.frame.DataFrame'>

RangeIndex: 120 entries

Data columns (total 11 columns)

Temp            int64
Humidity        int64
Cloud Cover     int64
Annual        float64
Flood          object
df.isnull().sum()
df.describe()
             Temp   Humidity  Annual
count      120.00   120.00    120.00
mean        29.20    74.10   3025.60
std          1.20     2.60    325.50
min         28.00    70.00   2065.30
25%         28.00    72.00   2780.10
50%         29.00    74.00   3048.80
75%         30.00    76.00   3278.90
max         31.00    79.00   3890.20
df.duplicated().sum()
df = df.drop_duplicates()
df.to_csv("clean_dataset.csv", index=False)
